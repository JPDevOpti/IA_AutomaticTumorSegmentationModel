# %%
from Scripts.utils import load_nii, extract_folder, show_subplots
from Scripts.co_registration import reorient_image
from Scripts.normalization import normalize_image
from Scripts.brain_extraction import extract_brain

# %%
# Rutas de los archivos .nii
nii_pre_processado = '../dataset/preprocessed/T1GD_not_processed/UPENN-GBM-00001_11_T1GD_unstripped.nii.gz';
nii_no_pre_processado = '../dataset/preprocessed/outputs/UPENN-GBM-00001_11_T1GD_unstripped.nii_brain_extracted.nii';

# Cargar las imágenes
imagen1 = load_nii(nii_pre_processado)
imagen2 = load_nii(nii_no_pre_processado)

# Mostrar las capas específicas en subgráficas
show_subplots(imagen1.get_fdata(), nii_pre_processado, imagen2.get_fdata(), nii_no_pre_processado, capa=50, indice_carpeta=3)
print(imagen1.shape)
print(imagen2.shape)
# Out:
# (240, 240, 155)
# (240, 240, 155)
